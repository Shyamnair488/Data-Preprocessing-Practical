# %%
import numpy as np
import pandas as pd

# %%
a=pd.read_csv("/content/a.csv")
a
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven
# 0       ritz  2014           3.35           5.59       27000
# 1        sx4  2013           4.75           9.54       43000
# 2       ciaz  2017           7.25           9.85        6900
# 3    wagon r  2011           2.85           4.15        5200
# 4      swift  2014           4.60           6.87       42450
# ..       ...   ...            ...            ...         ...
# 296     city  2016           9.50          11.60       33988
# 297     brio  2015           4.00           5.90       60000
# 298     city  2009           3.35          11.00       87934
# 299     city  2017          11.50          12.50        9000
# 300     brio  2016           5.30           5.90        5464
#
# [301 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
x = a['Year']
y = a['Selling_Price']
z = a['Present_Price']
w = a['Kms_Driven']
x_train, x_test, y_train, y_test , z_train, z_test, w_train, w_test = train_test_split(x,y,z,w ,test_size = 0.3, random_state = 10)

# %%
b1 = x_train
b2 = x_test
b3 = y_train 
b4 = y_test 
b5 = z_train
b6 = z_test
b7 = w_train
b8 = w_test

# %%
b1
# Out:
# 49     2017
# 169    2015
# 199    2007
# 58     2014
# 276    2015
#        ...
# 156    2017
# 123    2013
# 15     2016
# 125    2009
# 265    2017
# Name: Year, Length: 210, dtype: int64

# %%
b2
# Out:
# 258    2015
# 154    2014
# 227    2011
# 126    2017
# 268    2017
#        ...
# 69     2016
# 21     2017
# 208    2017
# 78     2010
# 172    2014
# Name: Year, Length: 91, dtype: int64

# %%
c
# Out:
# 49     7.75
# 169    0.40
# 199    0.12
# 58     4.10
# 276    8.65
#        ...
# 156    0.48
# 123    1.00
# 15     7.75
# 125    0.90
# 265    6.50
# Name: Selling_Price, Length: 210, dtype: float64

# %%
b4
# Out:
# 258     8.40
# 154     0.50
# 227     2.55
# 126     0.90
# 268     4.80
#        ...
# 69     14.25
# 21      4.90
# 208     7.90
# 78      5.25
# 172     0.40
# Name: Selling_Price, Length: 91, dtype: float64

# %%
b5
# Out:
# 49      9.29
# 169     0.54
# 199     0.58
# 58      6.80
# 276    13.60
#        ...
# 156     0.52
# 123     1.47
# 15     10.79
# 125     1.75
# 265     8.70
# Name: Present_Price, Length: 210, dtype: float64

# %%
b6
# Out:
# 258    13.60
# 154     0.88
# 227     4.43
# 126     0.95
# 268     5.80
#        ...
# 69     20.91
# 21      5.71
# 208     8.10
# 78     22.83
# 172     0.64
# Name: Present_Price, Length: 91, dtype: float64

# %%
b7
# Out:
# 49     37000
# 169    14000
# 199    53000
# 58     39485
# 276    24800
#        ...
# 156    15000
# 123    46500
# 15     43000
# 125    40000
# 265    21200
# Name: Kms_Driven, Length: 210, dtype: int64

# %%
b8
# Out:
# 258    25000
# 154     8000
# 227    57000
# 126     1300
# 268    19000
#        ...
# 69     12000
# 21      2400
# 208     3435
# 78     80000
# 172    13700
# Name: Kms_Driven, Length: 91, dtype: int64
